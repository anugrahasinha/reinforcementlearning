# %% [markdown]
# ## Tic-Tac-Toe Numerical - RL Agent Type : ODD : Agent plays ODD moves
#
# ##### Author : Anugraha Sinha
# ##### Email : anugraha[dot]sinha[at]gmail[dot]com
#
# In this notebook, we will build an RL agent (using Q-learning) that learns to play Numerical Tic-Tac-Toe with odd numbers. The environment is playing randomly with the agent, i.e. its strategy is to put an even number randomly in an empty cell. The following is the layout of the notebook:
#         - Defining epsilon-greedy strategy
#         - Tracking state-action pairs for convergence
#         - Define hyperparameters for the Q-learning algorithm
#         - Generating episode and applying Q-update equation
#         - Checking convergence in Q-values

# %% [markdown]
# #### Importing libraries
# Write the code to import Tic-Tac-Toe class from the environment file

# %%
import collections
import numpy as np
import random
import pickle
import collections
from matplotlib import pyplot as plt
import time
import os
from datetime import datetime
from itertools import groupby
from itertools import product

# %% [markdown]
# `class TicTacToe` acts as the ENVIRONMENT

# %%
class TicTacToe():

    def __init__(self):
        """initialise the board"""
        
        # initialise state as an array
        self.state = [np.nan for _ in range(9)]  # initialises the board position, can initialise to an array or matrix
        # all possible numbers
        self.all_possible_numbers = [i for i in range(1, len(self.state) + 1)] # , can initialise to an array or matrix

        self.reset()


    def is_winning(self, curr_state):
        """Takes state as an input and returns whether any row, column or diagonal has winning sum
        Example: Input state- [1, 2, 3, 4, nan, nan, nan, nan, nan]
        Output = False"""
        
        '''
        Comment from Anugraha Sinha:
        We are visualizing the game in following fashion (The number in boxes are the idx values of "self.states"
         ____________________
        |      |      |      |
        |   0  |   1  |   2  |
        |______|______|______|
        |      |      |      |
        |   3  |   4  |   5  |
        |______|______|______|
        |      |      |      |
        |   6  |   7  |   8  |
        |______|______|______|
        
        We use a strict way of checking the sum as 15, because np.diagonal provides only primary diagonal (top-left -> bottom-right)
        However, we would also want to check (top-right -> bottom-left), hence we do not follow the simple np.sum methods, but define the indexes individually
        '''
        horizontals = [[0,1,2],[3,4,5],[6,7,8]]
        verticals = [[0,3,6],[1,4,7],[2,5,8]]
        diagonals = [[0,4,8],[2,4,6]]
        
        hor_ans = list(filter(lambda x : np.sum(np.array(curr_state)[x]) == 15,horizontals))
        ver_ans = list(filter(lambda x : np.sum(np.array(curr_state)[x]) == 15,verticals))
        diag_ans = list(filter(lambda x : np.sum(np.array(curr_state)[x]) == 15,diagonals))
        
        if len(hor_ans) != 0 or len(ver_ans) != 0 or len(diag_ans) != 0:
            return True
        else:
            return False

    def is_terminal(self, curr_state):
        # Terminal state could be winning state or when the board is filled up

        if self.is_winning(curr_state) == True:
            return True, 'Win'

        elif len(self.allowed_positions(curr_state)) ==0:
            return True, 'Tie'

        else:
            return False, 'Resume'


    def allowed_positions(self, curr_state):
        """Takes state as an input and returns all indexes that are blank"""
        return [i for i, val in enumerate(curr_state) if np.isnan(val)]


    def allowed_values(self, curr_state):
        """Takes the current state as input and returns all possible (unused) values that can be placed on the board"""

        used_values = [val for val in curr_state if not np.isnan(val)]
        agent_values = [val for val in self.all_possible_numbers if val not in used_values and val % 2 !=0]
        env_values = [val for val in self.all_possible_numbers if val not in used_values and val % 2 ==0]

        return (agent_values, env_values)


    def action_space(self, curr_state):
        """Takes the current state as input and returns all possible actions, i.e, all combinations of allowed positions and allowed values"""

        agent_actions = product(self.allowed_positions(curr_state), self.allowed_values(curr_state)[0])
        env_actions = product(self.allowed_positions(curr_state), self.allowed_values(curr_state)[1])
        return (agent_actions, env_actions)



    def state_transition(self, curr_state, curr_action):
        """Takes current state and action and returns the board position just after agent's move.
        Example: Input state- [1, 2, 3, 4, nan, nan, nan, nan, nan], action- [9, 7]
        Output = [1, 2, 3, 4, nan, nan, nan, 9, nan]
        """
        
        '''
        Comment from Anugraha Sinha:
        As stated in the comment above, we will consider curr_action as a list which means
        curr_action = [position to be added, number to be added]
        
        Note : 
        1. "Position" is in python addressing system
        2. Action space returns (position,number) type of data.
        '''
        new_state = curr_state.copy()                  ## Important : Good if we copy things in order to avoid reference to same memory location #
        new_state[curr_action[0]] = curr_action[1]
        return new_state

    def step(self, curr_state, curr_action):
        """Takes current state and action and returns the next state, reward and whether the state is terminal. Hint: First, check the board position after
        agent's move, whether the game is won/loss/tied. Then incorporate environment's move and again check the board status.
        Example: Input state- [1, 2, 3, 4, nan, nan, nan, nan, nan], action- [9, 7]
        Output = ([1, 2, 3, 4, nan, nan, nan, 9, nan], -1, False)"""
        
        # update state with agent's action #
        new_state = self.state_transition(curr_state,curr_action)
        
        # check the status (win/loss/tie) after agent's move
        chk_terminal,message = self.is_terminal(new_state)
        
        if chk_terminal:
            # If we reached terminal state, display message
            #print("After agent's move, reached terminal state : %s" %(message))
            # If it was win, reward will be '10'
            if message == "Win":
                reward = 10
                msg = "Agent Won"
            # if it was tie, reward will '0'
            else:
                reward = 0
                msg = "Tie"
            return new_state,reward,chk_terminal,msg
        else:
            # It is not a terminal state after agent's move #
            # execute move for environment #
            
            # Environment's next action would be random selection from available action space #
            env_action = random.choice([ac for itr,ac in enumerate(self.action_space(new_state)[1])])
            
            # execute environment action #
            new_state = self.state_transition(new_state,env_action)
            
            # we should check if environment's action resulted in terminal state #
            chk_terminal_2, message_2 = self.is_terminal(new_state)
            
            if chk_terminal_2:
                # if we reached a terminal state #
                #print("After agent's action of : %s, environment took action as : %s. This led to terminal state : %s" %(str(curr_action),str(env_action),message_2))
                # if it was win by environment, then reward should be "-10"
                if message_2 == "Win":
                    reward = -10
                    msg = "Env Won"
                # if it was tie, reward will be '0'
                else:
                    reward = 0
                    msg = "Tie"
                return new_state,reward,chk_terminal_2,msg
            else:
                # even after environment action, we have "resume", and hence reward = "-1"
                reward = -1
                msg = "Continue"
                return new_state, reward, chk_terminal_2,msg
        
    def reset(self):
        return self.state
        
    def print_board(self,curr_state):
        printable_curr_state = ["X" if np.isnan(x) else str(x) for x in curr_state]
        return "    %s\n    %s\n    %s" %(str(np.array(printable_curr_state).reshape(3,3)[0,:]),str(np.array(printable_curr_state).reshape(3,3)[1,:]),str(np.array(printable_curr_state).reshape(3,3)[2,:]))

# %% [markdown]
# Creating a function to convert the [list] structure of states to a string based structure so that it could be added to Q_dict

# %%
# Function to convert state array into a string to store it as keys in the dictionary
# states in Q-dictionary will be of form: x-4-5-3-8-x-x-x-x
#   x | 4 | 5
#   ----------
#   3 | 8 | x
#   ----------
#   x | x | x

def Q_state(state):

    return ('-'.join(str(e) for e in state)).replace('nan','x')

# %% [markdown]
# **valid_actions** provides available action for the *agent* given a state of the game.

# %%
# Defining a function which will return valid (all possible actions) actions corresponding to a state
# Important to avoid errors during deployment.

def valid_actions(state):

    valid_Actions = []
    
    valid_Actions = [i for i in env.action_space(state)[0]]
    return valid_Actions

# %% [markdown]
# **add_to_dict** adds a state in *Q_dict* if it does not exist.
#
# * Remember, while adding the new state, all valid actions will also be added with a default q_value = 0

# %%
# Defining a function which will add new Q-values to the Q-dictionary. 
def add_to_dict(state):
    state1 = Q_state(state)
    
    valid_act = valid_actions(state)
    if state1 not in Q_dict.keys():
        for action in valid_act:
            Q_dict[state1][action]=0

# %% [markdown]
# #### Epsilon-greedy strategy
#
# We build an epsilon greedy strategy for controlling exploitation and exploration of the agent.
#
# Description of how epsilon greedy strategy works is provided in comments below.

# %%
# Defining epsilon-greedy policy. You can choose any function epsilon-decay strategy
exploitation = 0
exploration = 0
def select_action_epsilon_greedy(state,time):
    max_epsilon = 1.0
    min_epsilon = 0.001
    chk_epsilon_value = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-0.00001*time)
    random_value = np.random.random()
    
    # just testing #
    #chk_epsilon_value = -1
    
    # Comment from Anugraha Sinha #
    # As we play more number of games, "time" value will become higher and higher
    # This will lead to have the chk_epsilon_value to become smaller and smaller
    #
    # So as epsilon becomes smaller, we should follow a more "exploitation" strategy
    # When epsilon is higher, we should follow a more "exploration strategy"
    global exploitation
    global exploration
    if random_value > chk_epsilon_value:
        # This means we should follow an "exploitation" strategy
        proposed_action = max(Q_dict[Q_state(state)],key=Q_dict[Q_state(state)].get)
        exploitation += 1
    else:
        # This means we should follow an "exploration" strategy
        proposed_action = random.choice([ac for itr,ac in enumerate(env.action_space(state)[0])])
        exploration += 1
    return proposed_action

# %% [markdown]
# Initializing new Q_dict and States_tract

# %%
# Initialise Q_dictionary and States_tracked (for convergence)
Q_dict = collections.defaultdict(dict)
States_track = collections.defaultdict(dict)

# %% [markdown]
# The states chosen for States_action pairs to be tracked is based on the strategy that 5 positions on the board should be empty.
#
# Therefore, we have states which have 5 - "x" value in state's key.

# %%
def initialise_tracking_states():
    # Initialise states to be tracked
    # Based on the comment above, we will track following state,action pairs (10 in nos) #
    state_action_pair = [('x-7-3-x-2-8-x-x-x', (0, 1)),
                         ('x-1-2-x-7-x-x-8-x', (0, 3)),
                         ('6-x-2-x-x-3-x-x-1', (1, 5)),
                         ('6-x-7-x-x-1-x-x-4', (1, 3)),
                         ('x-x-x-4-9-2-7-x-x', (0, 1)),
                         ('x-x-3-8-2-x-x-x-5', (0, 1)),
                         ('3-x-7-x-x-x-x-8-2', (1, 5)),
                         ('x-x-1-8-2-7-x-x-x', (0, 3)),
                         ('x-1-x-x-x-x-8-6-7', (0, 3)),
                         ('x-9-x-x-6-8-x-x-5', (0, 1))]
    for st,ac in state_action_pair:
        States_track[st][ac] = list()

# %% [markdown]
# A standard function to save objs as pickle files.

# %%
#Defining a function to save the Q-dictionary as a pickle file
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ##### save_tracking_states
# we will execute this function after a few games have been played to store the change in q_values of the chosen state action pairs which are being tracked.

# %%
def save_tracking_states():
    for state in States_track.keys():
        for action in States_track[state].keys():
            if state in Q_dict and action in Q_dict[state]:
                States_track[state][action].append(Q_dict[state][action])

# %% [markdown]
# Initializing tracking states so that we can save the data.

# %%
initialise_tracking_states()

# %% [markdown]
# #### Define hyperparameters  (Exec 1)
# In this execution we do following
# * 5 million games to be played
# * Learning Rate : 0.01
# * Discount Factor : 0.91
# * Policy (Q_dict) : To be saved every 20000th game
# * Saved tracking states : To be saved every 20000th game
# * Success Values : Games won/lost/tie(s) to printed at every 10000th game.

# %%
EPISODES = 5000000
LR=0.01
GAMMA = 0.91
policy_threshold = 20000
save_tracking_state_threshold = 20000
episode_print_threshhold = 10000

# %% [markdown]
# ### Q-update loop (Exec1)

# %%
start_time = time.time()

dir_to_save = "./TicTacTor_Q_Value_Model_" + datetime.now().strftime("%Y%m%d_%H%M%S")
if not os.path.exists(dir_to_save):
    os.mkdir(dir_to_save)
    
agent_won_count = 0
agent_won_list = list()
env_won_count = 0
env_won_list = list()
tie_count = 0
tie_list = list()

total_reward = 0

for episode in range(EPISODES):
    ##### Start writing your code from the next line
    
    # Build a new environment for this episode #
    env = TicTacToe()
    current_state = env.state
    
    add_to_dict(current_state)
    
    # Since this an episodic task, therefore it will end at sometime
    # Hence we keep running and dont need to have a step calculating approach #
    
    stop_running = False
    while not stop_running:
        # get action as per epsilon strategy #
        # Remember, for 1 game we follow same strategy, however, next game we evolve our strategy.
        # Therefore for "select_action_epsilon_greedy", 2nd argument will be episode
        agent_action = select_action_epsilon_greedy(current_state,episode)
        
        # execute the action #
        next_state, reward, stop_running, msg = env.step(current_state,agent_action)
        
        # add the next state to the Q_dict, as this may be an entirely new state not seen before #
        # Also it may be that the next state is a terminal state, even then we add it to Q_dict
        # although we will never update the q_values for this (also given in question)
            
        add_to_dict(next_state)
        
        # save the reward #
        
        # if the next state is a terminal state, record the game status (won/lost/tie)
        # also remember that the next state (terminal states) q_value will be zero (0).
        # Update in Q_values of current_state,action should be taken care appropriately.
        if stop_running:
            # terminal state - either a tie or a win by agent or environment
            if msg == "Agent Won":
                agent_won_count += 1
            elif msg == "Env Won":
                env_won_count += 1
            else:
                tie_count += 1
            best_next_action = None
            # Remember in this case, the Q_value for next state will be 0, hence we do (reward + GAMMA* 0)
            Q_dict[Q_state(current_state)][agent_action] += LR * ((reward + (GAMMA*0)) - Q_dict[Q_state(current_state)][agent_action]) 
        else:
            # we update the current_state,agent_action reward based on "BEST" action possible for the next state #
            # we get the BEST ACTION for next_state and use that with the discount factor #
            best_next_action = max(Q_dict[Q_state(next_state)],key=Q_dict[Q_state(next_state)].get)
            Q_dict[Q_state(current_state)][agent_action] += LR * ((reward + (GAMMA*(Q_dict[Q_state(next_state)][best_next_action]))) - Q_dict[Q_state(current_state)][agent_action] ) 
    
        current_state = next_state
    
    agent_won_list.append(agent_won_count)
    env_won_list.append(env_won_count)
    tie_list.append(tie_count)
    
    if (episode + 1) % episode_print_threshhold == 0:
        print("After playing %d games, Agent Won : %.4f, Environment Won : %.4f, Tie(s) : %.4f" %(episode+1,agent_won_count/(episode+1),env_won_count/(episode+1),tie_count/(episode+1)))
    
    # If this is EPISODE is at threshold multiples, we will update the States_track for checking convergence
    if (episode + 1) % save_tracking_state_threshold == 0:
        save_tracking_states()
        #save_tracking_states_file = dir_to_save + "/Saved_tracking_states_itr_" + str(episode) + ".pickle"
        #save_obj(States_track,save_tracking_states_file)
        
    # If this EPISODE is at policy_threshold multiples, then we would save the policy model
    #if (episode + 1) % policy_threshold == 0:
        #q_value_policy_name = dir_to_save + "/Q_value_model_itr_" + str(episode) + ".pickle"
        #save_obj(Q_dict,q_value_policy_name)
        
elapsed_time = time.time() - start_time
print("Elapsed time :",elapsed_time)
# Out:
# After playing 10000 games, Agent Won : 0.2475, Environment Won : 0.2848, Tie(s) : 0.4677
# After playing 20000 games, Agent Won : 0.2467, Environment Won : 0.2839, Tie(s) : 0.4694
# After playing 30000 games, Agent Won : 0.2480, Environment Won : 0.2841, Tie(s) : 0.4679
# After playing 40000 games, Agent Won : 0.2490, Environment Won : 0.2830, Tie(s) : 0.4679
# After playing 50000 games, Agent Won : 0.2515, Environment Won : 0.2828, Tie(s) : 0.4657
# After playing 60000 games, Agent Won : 0.2527, Environment Won : 0.2818, Tie(s) : 0.4655
# After playing 70000 games, Agent Won : 0.2543, Environment Won : 0.2803, Tie(s) : 0.4654
# After playing 80000 games, Agent Won : 0.2562, Environment Won : 0.2795, Tie(s) : 0.4643
# After playing 90000 games, Agent Won : 0.2568, Environment Won : 0.2796, Tie(s) : 0.4636
# After playing 100000 games, Agent Won : 0.2585, Environment Won : 0.2790, Tie(s) : 0.4625
# After playing 110000 games, Agent Won : 0.2592, Environment Won : 0.2787, Tie(s) : 0.4621
# After playing 120000 games, Agent Won : 0.2604, Environment Won : 0.2784, Tie(s) : 0.4612
# After playing 130000 games, Agent Won : 0.2613, Environment Won : 0.2776, Tie(s) : 0.4611
# After playing 140000 games, Agent Won : 0.2622, Environment Won : 0.2775, Tie(s) : 0.4603
# After playing 150000 games, Agent Won : 0.2642, Environment Won : 0.2764, Tie(s) : 0.4594
# After playing 160000 games, Agent Won : 0.2654, Environment Won : 0.2756, Tie(s) : 0.4590
# After playing 170000 games, Agent Won : 0.2663, Environment Won : 0.2752, Tie(s) : 0.4585
# After playing 180000 games, Agent Won : 0.2678, Environment Won : 0.2743, Tie(s) : 0.4578
# After playing 190000 games, Agent Won : 0.2690, Environment Won : 0.2739, Tie(s) : 0.4571
# After playing 200000 games, Agent Won : 0.2705, Environment Won : 0.2732, Tie(s) : 0.4562
# After playing 210000 games, Agent Won : 0.2722, Environment Won : 0.2723, Tie(s) : 0.4555
# After playing 220000 games, Agent Won : 0.2732, Environment Won : 0.2720, Tie(s) : 0.4548
# After playing 230000 games, Agent Won : 0.2749, Environment Won : 0.2713, Tie(s) : 0.4538
# After playing 240000 games, Agent Won : 0.2763, Environment Won : 0.2704, Tie(s) : 0.4533
# After playing 250000 games, Agent Won : 0.2779, Environment Won : 0.2696, Tie(s) : 0.4525
# After playing 260000 games, Agent Won : 0.2793, Environment Won : 0.2689, Tie(s) : 0.4518
# After playing 270000 games, Agent Won : 0.2803, Environment Won : 0.2684, Tie(s) : 0.4513
# After playing 280000 games, Agent Won : 0.2816, Environment Won : 0.2677, Tie(s) : 0.4507
# After playing 290000 games, Agent Won : 0.2829, Environment Won : 0.2671, Tie(s) : 0.4500
# After playing 300000 games, Agent Won : 0.2845, Environment Won : 0.2662, Tie(s) : 0.4493
# After playing 310000 games, Agent Won : 0.2858, Environment Won : 0.2654, Tie(s) : 0.4488
# After playing 320000 games, Agent Won : 0.2870, Environment Won : 0.2647, Tie(s) : 0.4482
# After playing 330000 games, Agent Won : 0.2884, Environment Won : 0.2641, Tie(s) : 0.4475
# After playing 340000 games, Agent Won : 0.2899, Environment Won : 0.2631, Tie(s) : 0.4470
# After playing 350000 games, Agent Won : 0.2909, Environment Won : 0.2626, Tie(s) : 0.4464
# After playing 360000 games, Agent Won : 0.2922, Environment Won : 0.2620, Tie(s) : 0.4458
# After playing 370000 games, Agent Won : 0.2934, Environment Won : 0.2614, Tie(s) : 0.4452
# After playing 380000 games, Agent Won : 0.2945, Environment Won : 0.2609, Tie(s) : 0.4446
# After playing 390000 games, Agent Won : 0.2959, Environment Won : 0.2603, Tie(s) : 0.4438
# After playing 400000 games, Agent Won : 0.2971, Environment Won : 0.2599, Tie(s) : 0.4431
# After playing 410000 games, Agent Won : 0.2979, Environment Won : 0.2594, Tie(s) : 0.4426
# After playing 420000 games, Agent Won : 0.2993, Environment Won : 0.2589, Tie(s) : 0.4418
# After playing 430000 games, Agent Won : 0.3004, Environment Won : 0.2584, Tie(s) : 0.4412
# After playing 440000 games, Agent Won : 0.3015, Environment Won : 0.2580, Tie(s) : 0.4405
# After playing 450000 games, Agent Won : 0.3027, Environment Won : 0.2575, Tie(s) : 0.4398
# After playing 460000 games, Agent Won : 0.3038, Environment Won : 0.2570, Tie(s) : 0.4392
# After playing 470000 games, Agent Won : 0.3048, Environment Won : 0.2567, Tie(s) : 0.4385
# After playing 480000 games, Agent Won : 0.3057, Environment Won : 0.2564, Tie(s) : 0.4379
# After playing 490000 games, Agent Won : 0.3070, Environment Won : 0.2559, Tie(s) : 0.4370
# After playing 500000 games, Agent Won : 0.3081, Environment Won : 0.2556, Tie(s) : 0.4363
# After playing 510000 games, Agent Won : 0.3091, Environment Won : 0.2551, Tie(s) : 0.4358
# After playing 520000 games, Agent Won : 0.3100, Environment Won : 0.2549, Tie(s) : 0.4351
# After playing 530000 games, Agent Won : 0.3108, Environment Won : 0.2546, Tie(s) : 0.4346
# After playing 540000 games, Agent Won : 0.3118, Environment Won : 0.2542, Tie(s) : 0.4339
# After playing 550000 games, Agent Won : 0.3128, Environment Won : 0.2539, Tie(s) : 0.4333
# After playing 560000 games, Agent Won : 0.3137, Environment Won : 0.2535, Tie(s) : 0.4327
# After playing 570000 games, Agent Won : 0.3148, Environment Won : 0.2531, Tie(s) : 0.4320
# After playing 580000 games, Agent Won : 0.3156, Environment Won : 0.2528, Tie(s) : 0.4315
# After playing 590000 games, Agent Won : 0.3165, Environment Won : 0.2525, Tie(s) : 0.4310
# After playing 600000 games, Agent Won : 0.3174, Environment Won : 0.2522, Tie(s) : 0.4304
# After playing 610000 games, Agent Won : 0.3182, Environment Won : 0.2519, Tie(s) : 0.4299
# After playing 620000 games, Agent Won : 0.3191, Environment Won : 0.2517, Tie(s) : 0.4292
# After playing 630000 games, Agent Won : 0.3200, Environment Won : 0.2513, Tie(s) : 0.4287
# After playing 640000 games, Agent Won : 0.3211, Environment Won : 0.2510, Tie(s) : 0.4280
# After playing 650000 games, Agent Won : 0.3219, Environment Won : 0.2506, Tie(s) : 0.4275
# After playing 660000 games, Agent Won : 0.3228, Environment Won : 0.2503, Tie(s) : 0.4269
# After playing 670000 games, Agent Won : 0.3237, Environment Won : 0.2499, Tie(s) : 0.4264
# After playing 680000 games, Agent Won : 0.3246, Environment Won : 0.2495, Tie(s) : 0.4259
# After playing 690000 games, Agent Won : 0.3255, Environment Won : 0.2492, Tie(s) : 0.4253
# After playing 700000 games, Agent Won : 0.3263, Environment Won : 0.2489, Tie(s) : 0.4247
# After playing 710000 games, Agent Won : 0.3272, Environment Won : 0.2486, Tie(s) : 0.4242
# After playing 720000 games, Agent Won : 0.3281, Environment Won : 0.2481, Tie(s) : 0.4237
# After playing 730000 games, Agent Won : 0.3289, Environment Won : 0.2478, Tie(s) : 0.4232
# After playing 740000 games, Agent Won : 0.3299, Environment Won : 0.2476, Tie(s) : 0.4226
# After playing 750000 games, Agent Won : 0.3307, Environment Won : 0.2472, Tie(s) : 0.4221
# After playing 760000 games, Agent Won : 0.3315, Environment Won : 0.2469, Tie(s) : 0.4216
# After playing 770000 games, Agent Won : 0.3324, Environment Won : 0.2466, Tie(s) : 0.4210
# After playing 780000 games, Agent Won : 0.3333, Environment Won : 0.2462, Tie(s) : 0.4205
# After playing 790000 games, Agent Won : 0.3342, Environment Won : 0.2458, Tie(s) : 0.4199
# After playing 800000 games, Agent Won : 0.3350, Environment Won : 0.2455, Tie(s) : 0.4195
# After playing 810000 games, Agent Won : 0.3358, Environment Won : 0.2452, Tie(s) : 0.4190
# After playing 820000 games, Agent Won : 0.3368, Environment Won : 0.2448, Tie(s) : 0.4184
# After playing 830000 games, Agent Won : 0.3378, Environment Won : 0.2444, Tie(s) : 0.4178
# After playing 840000 games, Agent Won : 0.3386, Environment Won : 0.2441, Tie(s) : 0.4173
# After playing 850000 games, Agent Won : 0.3393, Environment Won : 0.2439, Tie(s) : 0.4168
# After playing 860000 games, Agent Won : 0.3402, Environment Won : 0.2436, Tie(s) : 0.4162
# After playing 870000 games, Agent Won : 0.3410, Environment Won : 0.2433, Tie(s) : 0.4157
# After playing 880000 games, Agent Won : 0.3419, Environment Won : 0.2430, Tie(s) : 0.4150
# After playing 890000 games, Agent Won : 0.3428, Environment Won : 0.2428, Tie(s) : 0.4144
# After playing 900000 games, Agent Won : 0.3436, Environment Won : 0.2424, Tie(s) : 0.4140
# After playing 910000 games, Agent Won : 0.3444, Environment Won : 0.2422, Tie(s) : 0.4134
# After playing 920000 games, Agent Won : 0.3452, Environment Won : 0.2419, Tie(s) : 0.4129
# After playing 930000 games, Agent Won : 0.3460, Environment Won : 0.2417, Tie(s) : 0.4123
# After playing 940000 games, Agent Won : 0.3468, Environment Won : 0.2414, Tie(s) : 0.4118
# After playing 950000 games, Agent Won : 0.3477, Environment Won : 0.2411, Tie(s) : 0.4112
# After playing 960000 games, Agent Won : 0.3485, Environment Won : 0.2408, Tie(s) : 0.4108
# After playing 970000 games, Agent Won : 0.3494, Environment Won : 0.2405, Tie(s) : 0.4102
# After playing 980000 games, Agent Won : 0.3502, Environment Won : 0.2401, Tie(s) : 0.4097
# After playing 990000 games, Agent Won : 0.3511, Environment Won : 0.2398, Tie(s) : 0.4091
# After playing 1000000 games, Agent Won : 0.3520, Environment Won : 0.2395, Tie(s) : 0.4085
# After playing 1010000 games, Agent Won : 0.3529, Environment Won : 0.2391, Tie(s) : 0.4079
# After playing 1020000 games, Agent Won : 0.3538, Environment Won : 0.2388, Tie(s) : 0.4074
# After playing 1030000 games, Agent Won : 0.3546, Environment Won : 0.2385, Tie(s) : 0.4069
# After playing 1040000 games, Agent Won : 0.3555, Environment Won : 0.2381, Tie(s) : 0.4064
# After playing 1050000 games, Agent Won : 0.3563, Environment Won : 0.2379, Tie(s) : 0.4059
# After playing 1060000 games, Agent Won : 0.3572, Environment Won : 0.2376, Tie(s) : 0.4053
# After playing 1070000 games, Agent Won : 0.3580, Environment Won : 0.2373, Tie(s) : 0.4047
# After playing 1080000 games, Agent Won : 0.3589, Environment Won : 0.2370, Tie(s) : 0.4041
# After playing 1090000 games, Agent Won : 0.3598, Environment Won : 0.2367, Tie(s) : 0.4034
# After playing 1100000 games, Agent Won : 0.3608, Environment Won : 0.2364, Tie(s) : 0.4028
# After playing 1110000 games, Agent Won : 0.3617, Environment Won : 0.2361, Tie(s) : 0.4022
# After playing 1120000 games, Agent Won : 0.3627, Environment Won : 0.2357, Tie(s) : 0.4015
# After playing 1130000 games, Agent Won : 0.3637, Environment Won : 0.2353, Tie(s) : 0.4009
# After playing 1140000 games, Agent Won : 0.3649, Environment Won : 0.2349, Tie(s) : 0.4002
# After playing 1150000 games, Agent Won : 0.3670, Environment Won : 0.2342, Tie(s) : 0.3988
# After playing 1160000 games, Agent Won : 0.3698, Environment Won : 0.2331, Tie(s) : 0.3971
# After playing 1170000 games, Agent Won : 0.3731, Environment Won : 0.2319, Tie(s) : 0.3950
# After playing 1180000 games, Agent Won : 0.3767, Environment Won : 0.2306, Tie(s) : 0.3927
# After playing 1190000 games, Agent Won : 0.3806, Environment Won : 0.2292, Tie(s) : 0.3902
# After playing 1200000 games, Agent Won : 0.3844, Environment Won : 0.2278, Tie(s) : 0.3878
# After playing 1210000 games, Agent Won : 0.3883, Environment Won : 0.2264, Tie(s) : 0.3854
# After playing 1220000 games, Agent Won : 0.3920, Environment Won : 0.2250, Tie(s) : 0.3830
# After playing 1230000 games, Agent Won : 0.3957, Environment Won : 0.2236, Tie(s) : 0.3807
# After playing 1240000 games, Agent Won : 0.3993, Environment Won : 0.2222, Tie(s) : 0.3784
# After playing 1250000 games, Agent Won : 0.4030, Environment Won : 0.2209, Tie(s) : 0.3761
# After playing 1260000 games, Agent Won : 0.4066, Environment Won : 0.2196, Tie(s) : 0.3739
# After playing 1270000 games, Agent Won : 0.4101, Environment Won : 0.2183, Tie(s) : 0.3716
# After playing 1280000 games, Agent Won : 0.4136, Environment Won : 0.2170, Tie(s) : 0.3695
# After playing 1290000 games, Agent Won : 0.4171, Environment Won : 0.2156, Tie(s) : 0.3673
# After playing 1300000 games, Agent Won : 0.4205, Environment Won : 0.2143, Tie(s) : 0.3652
# After playing 1310000 games, Agent Won : 0.4239, Environment Won : 0.2131, Tie(s) : 0.3630
# After playing 1320000 games, Agent Won : 0.4273, Environment Won : 0.2118, Tie(s) : 0.3609
# After playing 1330000 games, Agent Won : 0.4307, Environment Won : 0.2105, Tie(s) : 0.3588
# After playing 1340000 games, Agent Won : 0.4340, Environment Won : 0.2093, Tie(s) : 0.3567
# After playing 1350000 games, Agent Won : 0.4372, Environment Won : 0.2081, Tie(s) : 0.3547
# After playing 1360000 games, Agent Won : 0.4405, Environment Won : 0.2069, Tie(s) : 0.3526
# After playing 1370000 games, Agent Won : 0.4437, Environment Won : 0.2057, Tie(s) : 0.3506
# After playing 1380000 games, Agent Won : 0.4470, Environment Won : 0.2044, Tie(s) : 0.3486
# After playing 1390000 games, Agent Won : 0.4502, Environment Won : 0.2032, Tie(s) : 0.3466
# After playing 1400000 games, Agent Won : 0.4533, Environment Won : 0.2021, Tie(s) : 0.3446
# After playing 1410000 games, Agent Won : 0.4565, Environment Won : 0.2009, Tie(s) : 0.3426
# After playing 1420000 games, Agent Won : 0.4595, Environment Won : 0.1997, Tie(s) : 0.3407
# After playing 1430000 games, Agent Won : 0.4626, Environment Won : 0.1986, Tie(s) : 0.3388
# After playing 1440000 games, Agent Won : 0.4657, Environment Won : 0.1974, Tie(s) : 0.3369
# After playing 1450000 games, Agent Won : 0.4688, Environment Won : 0.1963, Tie(s) : 0.3350
# After playing 1460000 games, Agent Won : 0.4717, Environment Won : 0.1951, Tie(s) : 0.3331
# After playing 1470000 games, Agent Won : 0.4747, Environment Won : 0.1940, Tie(s) : 0.3313
# After playing 1480000 games, Agent Won : 0.4777, Environment Won : 0.1929, Tie(s) : 0.3294
# After playing 1490000 games, Agent Won : 0.4806, Environment Won : 0.1918, Tie(s) : 0.3276
# After playing 1500000 games, Agent Won : 0.4835, Environment Won : 0.1907, Tie(s) : 0.3257
# After playing 1510000 games, Agent Won : 0.4864, Environment Won : 0.1896, Tie(s) : 0.3239
# After playing 1520000 games, Agent Won : 0.4893, Environment Won : 0.1886, Tie(s) : 0.3221
# After playing 1530000 games, Agent Won : 0.4922, Environment Won : 0.1875, Tie(s) : 0.3203
# After playing 1540000 games, Agent Won : 0.4950, Environment Won : 0.1864, Tie(s) : 0.3185
# After playing 1550000 games, Agent Won : 0.4978, Environment Won : 0.1854, Tie(s) : 0.3168
# After playing 1560000 games, Agent Won : 0.5006, Environment Won : 0.1844, Tie(s) : 0.3151
# After playing 1570000 games, Agent Won : 0.5033, Environment Won : 0.1833, Tie(s) : 0.3133
# After playing 1580000 games, Agent Won : 0.5060, Environment Won : 0.1823, Tie(s) : 0.3116
# After playing 1590000 games, Agent Won : 0.5087, Environment Won : 0.1813, Tie(s) : 0.3099
# After playing 1600000 games, Agent Won : 0.5114, Environment Won : 0.1803, Tie(s) : 0.3083
# After playing 1610000 games, Agent Won : 0.5140, Environment Won : 0.1794, Tie(s) : 0.3066
# After playing 1620000 games, Agent Won : 0.5166, Environment Won : 0.1784, Tie(s) : 0.3050
# After playing 1630000 games, Agent Won : 0.5192, Environment Won : 0.1774, Tie(s) : 0.3034
# After playing 1640000 games, Agent Won : 0.5217, Environment Won : 0.1765, Tie(s) : 0.3018
# After playing 1650000 games, Agent Won : 0.5242, Environment Won : 0.1756, Tie(s) : 0.3002
# After playing 1660000 games, Agent Won : 0.5268, Environment Won : 0.1746, Tie(s) : 0.2986
# After playing 1670000 games, Agent Won : 0.5292, Environment Won : 0.1737, Tie(s) : 0.2971
# After playing 1680000 games, Agent Won : 0.5317, Environment Won : 0.1728, Tie(s) : 0.2955
# After playing 1690000 games, Agent Won : 0.5341, Environment Won : 0.1719, Tie(s) : 0.2940
# After playing 1700000 games, Agent Won : 0.5364, Environment Won : 0.1710, Tie(s) : 0.2926
# After playing 1710000 games, Agent Won : 0.5388, Environment Won : 0.1701, Tie(s) : 0.2911
# After playing 1720000 games, Agent Won : 0.5411, Environment Won : 0.1693, Tie(s) : 0.2896
# After playing 1730000 games, Agent Won : 0.5435, Environment Won : 0.1684, Tie(s) : 0.2881
# After playing 1740000 games, Agent Won : 0.5457, Environment Won : 0.1676, Tie(s) : 0.2867
# After playing 1750000 games, Agent Won : 0.5480, Environment Won : 0.1667, Tie(s) : 0.2853
# After playing 1760000 games, Agent Won : 0.5502, Environment Won : 0.1659, Tie(s) : 0.2839
# After playing 1770000 games, Agent Won : 0.5525, Environment Won : 0.1651, Tie(s) : 0.2825
# After playing 1780000 games, Agent Won : 0.5546, Environment Won : 0.1643, Tie(s) : 0.2811
# After playing 1790000 games, Agent Won : 0.5568, Environment Won : 0.1635, Tie(s) : 0.2797
# After playing 1800000 games, Agent Won : 0.5590, Environment Won : 0.1627, Tie(s) : 0.2783
# After playing 1810000 games, Agent Won : 0.5611, Environment Won : 0.1619, Tie(s) : 0.2770
# After playing 1820000 games, Agent Won : 0.5631, Environment Won : 0.1611, Tie(s) : 0.2757
# After playing 1830000 games, Agent Won : 0.5652, Environment Won : 0.1604, Tie(s) : 0.2744
# After playing 1840000 games, Agent Won : 0.5673, Environment Won : 0.1596, Tie(s) : 0.2731
# After playing 1850000 games, Agent Won : 0.5693, Environment Won : 0.1588, Tie(s) : 0.2719
# After playing 1860000 games, Agent Won : 0.5713, Environment Won : 0.1581, Tie(s) : 0.2706
# After playing 1870000 games, Agent Won : 0.5733, Environment Won : 0.1574, Tie(s) : 0.2693
# After playing 1880000 games, Agent Won : 0.5752, Environment Won : 0.1566, Tie(s) : 0.2681
# After playing 1890000 games, Agent Won : 0.5772, Environment Won : 0.1559, Tie(s) : 0.2669
# After playing 1900000 games, Agent Won : 0.5791, Environment Won : 0.1552, Tie(s) : 0.2656
# After playing 1910000 games, Agent Won : 0.5811, Environment Won : 0.1545, Tie(s) : 0.2644
# After playing 1920000 games, Agent Won : 0.5830, Environment Won : 0.1538, Tie(s) : 0.2632
# After playing 1930000 games, Agent Won : 0.5848, Environment Won : 0.1531, Tie(s) : 0.2621
# After playing 1940000 games, Agent Won : 0.5866, Environment Won : 0.1525, Tie(s) : 0.2609
# After playing 1950000 games, Agent Won : 0.5885, Environment Won : 0.1518, Tie(s) : 0.2597
# After playing 1960000 games, Agent Won : 0.5903, Environment Won : 0.1511, Tie(s) : 0.2586
# After playing 1970000 games, Agent Won : 0.5921, Environment Won : 0.1505, Tie(s) : 0.2574
# After playing 1980000 games, Agent Won : 0.5939, Environment Won : 0.1498, Tie(s) : 0.2563
# After playing 1990000 games, Agent Won : 0.5957, Environment Won : 0.1491, Tie(s) : 0.2552
# After playing 2000000 games, Agent Won : 0.5974, Environment Won : 0.1485, Tie(s) : 0.2541
# After playing 2010000 games, Agent Won : 0.5991, Environment Won : 0.1479, Tie(s) : 0.2530
# After playing 2020000 games, Agent Won : 0.6007, Environment Won : 0.1473, Tie(s) : 0.2520
# After playing 2030000 games, Agent Won : 0.6024, Environment Won : 0.1467, Tie(s) : 0.2509
# After playing 2040000 games, Agent Won : 0.6041, Environment Won : 0.1460, Tie(s) : 0.2499
# After playing 2050000 games, Agent Won : 0.6057, Environment Won : 0.1454, Tie(s) : 0.2488
# After playing 2060000 games, Agent Won : 0.6074, Environment Won : 0.1448, Tie(s) : 0.2478
# After playing 2070000 games, Agent Won : 0.6090, Environment Won : 0.1442, Tie(s) : 0.2468
# After playing 2080000 games, Agent Won : 0.6106, Environment Won : 0.1436, Tie(s) : 0.2458
# After playing 2090000 games, Agent Won : 0.6122, Environment Won : 0.1430, Tie(s) : 0.2447
# After playing 2100000 games, Agent Won : 0.6138, Environment Won : 0.1425, Tie(s) : 0.2437
# After playing 2110000 games, Agent Won : 0.6154, Environment Won : 0.1419, Tie(s) : 0.2428
# After playing 2120000 games, Agent Won : 0.6169, Environment Won : 0.1413, Tie(s) : 0.2418
# After playing 2130000 games, Agent Won : 0.6185, Environment Won : 0.1407, Tie(s) : 0.2408
# After playing 2140000 games, Agent Won : 0.6200, Environment Won : 0.1402, Tie(s) : 0.2398
# After playing 2150000 games, Agent Won : 0.6215, Environment Won : 0.1396, Tie(s) : 0.2389
# After playing 2160000 games, Agent Won : 0.6230, Environment Won : 0.1391, Tie(s) : 0.2380
# After playing 2170000 games, Agent Won : 0.6245, Environment Won : 0.1385, Tie(s) : 0.2370
# After playing 2180000 games, Agent Won : 0.6259, Environment Won : 0.1380, Tie(s) : 0.2361
# After playing 2190000 games, Agent Won : 0.6273, Environment Won : 0.1375, Tie(s) : 0.2352
# After playing 2200000 games, Agent Won : 0.6288, Environment Won : 0.1369, Tie(s) : 0.2343
# After playing 2210000 games, Agent Won : 0.6302, Environment Won : 0.1364, Tie(s) : 0.2334
# After playing 2220000 games, Agent Won : 0.6316, Environment Won : 0.1359, Tie(s) : 0.2325
# After playing 2230000 games, Agent Won : 0.6330, Environment Won : 0.1354, Tie(s) : 0.2316
# After playing 2240000 games, Agent Won : 0.6344, Environment Won : 0.1348, Tie(s) : 0.2307
# After playing 2250000 games, Agent Won : 0.6358, Environment Won : 0.1343, Tie(s) : 0.2299
# After playing 2260000 games, Agent Won : 0.6372, Environment Won : 0.1338, Tie(s) : 0.2290
# After playing 2270000 games, Agent Won : 0.6385, Environment Won : 0.1333, Tie(s) : 0.2282
# After playing 2280000 games, Agent Won : 0.6398, Environment Won : 0.1328, Tie(s) : 0.2273
# After playing 2290000 games, Agent Won : 0.6412, Environment Won : 0.1323, Tie(s) : 0.2265
# After playing 2300000 games, Agent Won : 0.6425, Environment Won : 0.1319, Tie(s) : 0.2257
# After playing 2310000 games, Agent Won : 0.6438, Environment Won : 0.1314, Tie(s) : 0.2248
# After playing 2320000 games, Agent Won : 0.6451, Environment Won : 0.1309, Tie(s) : 0.2240
# After playing 2330000 games, Agent Won : 0.6463, Environment Won : 0.1304, Tie(s) : 0.2232
# After playing 2340000 games, Agent Won : 0.6476, Environment Won : 0.1299, Tie(s) : 0.2224
# After playing 2350000 games, Agent Won : 0.6489, Environment Won : 0.1295, Tie(s) : 0.2216
# After playing 2360000 games, Agent Won : 0.6501, Environment Won : 0.1290, Tie(s) : 0.2208
# After playing 2370000 games, Agent Won : 0.6514, Environment Won : 0.1285, Tie(s) : 0.2201
# After playing 2380000 games, Agent Won : 0.6526, Environment Won : 0.1281, Tie(s) : 0.2193
# After playing 2390000 games, Agent Won : 0.6538, Environment Won : 0.1276, Tie(s) : 0.2185
# After playing 2400000 games, Agent Won : 0.6550, Environment Won : 0.1272, Tie(s) : 0.2178
# After playing 2410000 games, Agent Won : 0.6562, Environment Won : 0.1268, Tie(s) : 0.2170
# After playing 2420000 games, Agent Won : 0.6574, Environment Won : 0.1263, Tie(s) : 0.2163
# After playing 2430000 games, Agent Won : 0.6586, Environment Won : 0.1259, Tie(s) : 0.2155
# After playing 2440000 games, Agent Won : 0.6597, Environment Won : 0.1255, Tie(s) : 0.2148
# After playing 2450000 games, Agent Won : 0.6609, Environment Won : 0.1250, Tie(s) : 0.2141
# After playing 2460000 games, Agent Won : 0.6620, Environment Won : 0.1246, Tie(s) : 0.2134
# After playing 2470000 games, Agent Won : 0.6632, Environment Won : 0.1242, Tie(s) : 0.2126
# After playing 2480000 games, Agent Won : 0.6643, Environment Won : 0.1238, Tie(s) : 0.2119
# After playing 2490000 games, Agent Won : 0.6654, Environment Won : 0.1233, Tie(s) : 0.2112
# After playing 2500000 games, Agent Won : 0.6666, Environment Won : 0.1229, Tie(s) : 0.2105
# After playing 2510000 games, Agent Won : 0.6676, Environment Won : 0.1225, Tie(s) : 0.2098
# After playing 2520000 games, Agent Won : 0.6687, Environment Won : 0.1221, Tie(s) : 0.2092
# After playing 2530000 games, Agent Won : 0.6698, Environment Won : 0.1217, Tie(s) : 0.2085
# After playing 2540000 games, Agent Won : 0.6709, Environment Won : 0.1213, Tie(s) : 0.2078
# After playing 2550000 games, Agent Won : 0.6720, Environment Won : 0.1209, Tie(s) : 0.2071
# After playing 2560000 games, Agent Won : 0.6730, Environment Won : 0.1205, Tie(s) : 0.2065
# After playing 2570000 games, Agent Won : 0.6741, Environment Won : 0.1201, Tie(s) : 0.2058
# After playing 2580000 games, Agent Won : 0.6751, Environment Won : 0.1197, Tie(s) : 0.2052
# After playing 2590000 games, Agent Won : 0.6761, Environment Won : 0.1194, Tie(s) : 0.2045
# After playing 2600000 games, Agent Won : 0.6771, Environment Won : 0.1190, Tie(s) : 0.2039
# After playing 2610000 games, Agent Won : 0.6782, Environment Won : 0.1186, Tie(s) : 0.2032
# After playing 2620000 games, Agent Won : 0.6792, Environment Won : 0.1182, Tie(s) : 0.2026
# After playing 2630000 games, Agent Won : 0.6802, Environment Won : 0.1179, Tie(s) : 0.2020
# After playing 2640000 games, Agent Won : 0.6812, Environment Won : 0.1175, Tie(s) : 0.2014
# After playing 2650000 games, Agent Won : 0.6822, Environment Won : 0.1171, Tie(s) : 0.2007
# After playing 2660000 games, Agent Won : 0.6831, Environment Won : 0.1167, Tie(s) : 0.2001
# After playing 2670000 games, Agent Won : 0.6841, Environment Won : 0.1164, Tie(s) : 0.1995
# After playing 2680000 games, Agent Won : 0.6851, Environment Won : 0.1160, Tie(s) : 0.1989
# After playing 2690000 games, Agent Won : 0.6860, Environment Won : 0.1157, Tie(s) : 0.1983
# After playing 2700000 games, Agent Won : 0.6870, Environment Won : 0.1153, Tie(s) : 0.1977
# After playing 2710000 games, Agent Won : 0.6879, Environment Won : 0.1149, Tie(s) : 0.1971
# After playing 2720000 games, Agent Won : 0.6889, Environment Won : 0.1146, Tie(s) : 0.1965
# After playing 2730000 games, Agent Won : 0.6898, Environment Won : 0.1143, Tie(s) : 0.1959
# After playing 2740000 games, Agent Won : 0.6907, Environment Won : 0.1139, Tie(s) : 0.1954
# After playing 2750000 games, Agent Won : 0.6916, Environment Won : 0.1136, Tie(s) : 0.1948
# After playing 2760000 games, Agent Won : 0.6925, Environment Won : 0.1132, Tie(s) : 0.1942
# After playing 2770000 games, Agent Won : 0.6934, Environment Won : 0.1129, Tie(s) : 0.1937
# After playing 2780000 games, Agent Won : 0.6943, Environment Won : 0.1126, Tie(s) : 0.1931
# After playing 2790000 games, Agent Won : 0.6952, Environment Won : 0.1122, Tie(s) : 0.1926
# After playing 2800000 games, Agent Won : 0.6961, Environment Won : 0.1119, Tie(s) : 0.1920
# After playing 2810000 games, Agent Won : 0.6970, Environment Won : 0.1116, Tie(s) : 0.1915
# After playing 2820000 games, Agent Won : 0.6978, Environment Won : 0.1112, Tie(s) : 0.1909
# After playing 2830000 games, Agent Won : 0.6987, Environment Won : 0.1109, Tie(s) : 0.1904
# After playing 2840000 games, Agent Won : 0.6996, Environment Won : 0.1106, Tie(s) : 0.1898
# After playing 2850000 games, Agent Won : 0.7004, Environment Won : 0.1103, Tie(s) : 0.1893
# After playing 2860000 games, Agent Won : 0.7013, Environment Won : 0.1100, Tie(s) : 0.1888
# After playing 2870000 games, Agent Won : 0.7021, Environment Won : 0.1096, Tie(s) : 0.1883
# After playing 2880000 games, Agent Won : 0.7029, Environment Won : 0.1093, Tie(s) : 0.1877
# After playing 2890000 games, Agent Won : 0.7038, Environment Won : 0.1090, Tie(s) : 0.1872
# After playing 2900000 games, Agent Won : 0.7046, Environment Won : 0.1087, Tie(s) : 0.1867
# After playing 2910000 games, Agent Won : 0.7054, Environment Won : 0.1084, Tie(s) : 0.1862
# After playing 2920000 games, Agent Won : 0.7062, Environment Won : 0.1081, Tie(s) : 0.1857
# After playing 2930000 games, Agent Won : 0.7070, Environment Won : 0.1078, Tie(s) : 0.1852
# After playing 2940000 games, Agent Won : 0.7078, Environment Won : 0.1075, Tie(s) : 0.1847
# After playing 2950000 games, Agent Won : 0.7086, Environment Won : 0.1072, Tie(s) : 0.1842
# After playing 2960000 games, Agent Won : 0.7094, Environment Won : 0.1069, Tie(s) : 0.1837
# After playing 2970000 games, Agent Won : 0.7102, Environment Won : 0.1066, Tie(s) : 0.1832
# After playing 2980000 games, Agent Won : 0.7110, Environment Won : 0.1063, Tie(s) : 0.1827
# After playing 2990000 games, Agent Won : 0.7118, Environment Won : 0.1060, Tie(s) : 0.1822
# After playing 3000000 games, Agent Won : 0.7125, Environment Won : 0.1057, Tie(s) : 0.1817
# After playing 3010000 games, Agent Won : 0.7133, Environment Won : 0.1054, Tie(s) : 0.1813
# After playing 3020000 games, Agent Won : 0.7141, Environment Won : 0.1052, Tie(s) : 0.1808
# After playing 3030000 games, Agent Won : 0.7148, Environment Won : 0.1049, Tie(s) : 0.1803
# After playing 3040000 games, Agent Won : 0.7156, Environment Won : 0.1046, Tie(s) : 0.1798
# After playing 3050000 games, Agent Won : 0.7163, Environment Won : 0.1043, Tie(s) : 0.1793
# After playing 3060000 games, Agent Won : 0.7171, Environment Won : 0.1041, Tie(s) : 0.1789
# After playing 3070000 games, Agent Won : 0.7178, Environment Won : 0.1038, Tie(s) : 0.1784
# After playing 3080000 games, Agent Won : 0.7186, Environment Won : 0.1035, Tie(s) : 0.1779
# After playing 3090000 games, Agent Won : 0.7193, Environment Won : 0.1032, Tie(s) : 0.1775
# After playing 3100000 games, Agent Won : 0.7200, Environment Won : 0.1030, Tie(s) : 0.1770
# After playing 3110000 games, Agent Won : 0.7207, Environment Won : 0.1027, Tie(s) : 0.1766
# After playing 3120000 games, Agent Won : 0.7215, Environment Won : 0.1024, Tie(s) : 0.1761
# After playing 3130000 games, Agent Won : 0.7222, Environment Won : 0.1022, Tie(s) : 0.1757
# After playing 3140000 games, Agent Won : 0.7229, Environment Won : 0.1019, Tie(s) : 0.1752
# After playing 3150000 games, Agent Won : 0.7236, Environment Won : 0.1016, Tie(s) : 0.1748
# After playing 3160000 games, Agent Won : 0.7243, Environment Won : 0.1014, Tie(s) : 0.1743
# After playing 3170000 games, Agent Won : 0.7250, Environment Won : 0.1011, Tie(s) : 0.1739
# After playing 3180000 games, Agent Won : 0.7257, Environment Won : 0.1009, Tie(s) : 0.1735
# After playing 3190000 games, Agent Won : 0.7264, Environment Won : 0.1006, Tie(s) : 0.1730
# After playing 3200000 games, Agent Won : 0.7270, Environment Won : 0.1004, Tie(s) : 0.1726
# After playing 3210000 games, Agent Won : 0.7277, Environment Won : 0.1001, Tie(s) : 0.1722
# After playing 3220000 games, Agent Won : 0.7284, Environment Won : 0.0999, Tie(s) : 0.1717
# After playing 3230000 games, Agent Won : 0.7291, Environment Won : 0.0996, Tie(s) : 0.1713
# After playing 3240000 games, Agent Won : 0.7297, Environment Won : 0.0994, Tie(s) : 0.1709
# After playing 3250000 games, Agent Won : 0.7304, Environment Won : 0.0991, Tie(s) : 0.1705
# After playing 3260000 games, Agent Won : 0.7310, Environment Won : 0.0989, Tie(s) : 0.1701
# After playing 3270000 games, Agent Won : 0.7317, Environment Won : 0.0986, Tie(s) : 0.1697
# After playing 3280000 games, Agent Won : 0.7323, Environment Won : 0.0984, Tie(s) : 0.1692
# After playing 3290000 games, Agent Won : 0.7330, Environment Won : 0.0982, Tie(s) : 0.1688
# After playing 3300000 games, Agent Won : 0.7336, Environment Won : 0.0979, Tie(s) : 0.1684
# After playing 3310000 games, Agent Won : 0.7343, Environment Won : 0.0977, Tie(s) : 0.1680
# After playing 3320000 games, Agent Won : 0.7349, Environment Won : 0.0974, Tie(s) : 0.1676
# After playing 3330000 games, Agent Won : 0.7356, Environment Won : 0.0972, Tie(s) : 0.1672
# After playing 3340000 games, Agent Won : 0.7362, Environment Won : 0.0970, Tie(s) : 0.1668
# After playing 3350000 games, Agent Won : 0.7368, Environment Won : 0.0967, Tie(s) : 0.1665
# After playing 3360000 games, Agent Won : 0.7374, Environment Won : 0.0965, Tie(s) : 0.1661
# After playing 3370000 games, Agent Won : 0.7380, Environment Won : 0.0963, Tie(s) : 0.1657
# After playing 3380000 games, Agent Won : 0.7386, Environment Won : 0.0961, Tie(s) : 0.1653
# After playing 3390000 games, Agent Won : 0.7392, Environment Won : 0.0958, Tie(s) : 0.1649
# After playing 3400000 games, Agent Won : 0.7398, Environment Won : 0.0956, Tie(s) : 0.1645
# After playing 3410000 games, Agent Won : 0.7404, Environment Won : 0.0954, Tie(s) : 0.1642
# After playing 3420000 games, Agent Won : 0.7410, Environment Won : 0.0952, Tie(s) : 0.1638
# After playing 3430000 games, Agent Won : 0.7416, Environment Won : 0.0949, Tie(s) : 0.1634
# After playing 3440000 games, Agent Won : 0.7422, Environment Won : 0.0947, Tie(s) : 0.1631
# After playing 3450000 games, Agent Won : 0.7428, Environment Won : 0.0945, Tie(s) : 0.1627
# After playing 3460000 games, Agent Won : 0.7434, Environment Won : 0.0943, Tie(s) : 0.1623
# After playing 3470000 games, Agent Won : 0.7440, Environment Won : 0.0941, Tie(s) : 0.1620
# After playing 3480000 games, Agent Won : 0.7445, Environment Won : 0.0939, Tie(s) : 0.1616
# After playing 3490000 games, Agent Won : 0.7451, Environment Won : 0.0936, Tie(s) : 0.1612
# After playing 3500000 games, Agent Won : 0.7457, Environment Won : 0.0934, Tie(s) : 0.1609
# After playing 3510000 games, Agent Won : 0.7463, Environment Won : 0.0932, Tie(s) : 0.1605
# After playing 3520000 games, Agent Won : 0.7468, Environment Won : 0.0930, Tie(s) : 0.1602
# After playing 3530000 games, Agent Won : 0.7474, Environment Won : 0.0928, Tie(s) : 0.1598
# After playing 3540000 games, Agent Won : 0.7479, Environment Won : 0.0926, Tie(s) : 0.1595
# After playing 3550000 games, Agent Won : 0.7485, Environment Won : 0.0924, Tie(s) : 0.1591
# After playing 3560000 games, Agent Won : 0.7490, Environment Won : 0.0922, Tie(s) : 0.1588
# After playing 3570000 games, Agent Won : 0.7496, Environment Won : 0.0920, Tie(s) : 0.1585
# After playing 3580000 games, Agent Won : 0.7501, Environment Won : 0.0918, Tie(s) : 0.1581
# After playing 3590000 games, Agent Won : 0.7506, Environment Won : 0.0916, Tie(s) : 0.1578
# After playing 3600000 games, Agent Won : 0.7512, Environment Won : 0.0914, Tie(s) : 0.1574
# After playing 3610000 games, Agent Won : 0.7517, Environment Won : 0.0912, Tie(s) : 0.1571
# After playing 3620000 games, Agent Won : 0.7522, Environment Won : 0.0910, Tie(s) : 0.1568
# After playing 3630000 games, Agent Won : 0.7528, Environment Won : 0.0908, Tie(s) : 0.1564
# After playing 3640000 games, Agent Won : 0.7533, Environment Won : 0.0906, Tie(s) : 0.1561
# After playing 3650000 games, Agent Won : 0.7538, Environment Won : 0.0904, Tie(s) : 0.1558
# After playing 3660000 games, Agent Won : 0.7543, Environment Won : 0.0902, Tie(s) : 0.1555
# After playing 3670000 games, Agent Won : 0.7549, Environment Won : 0.0900, Tie(s) : 0.1551
# After playing 3680000 games, Agent Won : 0.7554, Environment Won : 0.0898, Tie(s) : 0.1548
# After playing 3690000 games, Agent Won : 0.7559, Environment Won : 0.0896, Tie(s) : 0.1545
# After playing 3700000 games, Agent Won : 0.7564, Environment Won : 0.0894, Tie(s) : 0.1542
# After playing 3710000 games, Agent Won : 0.7569, Environment Won : 0.0893, Tie(s) : 0.1539
# After playing 3720000 games, Agent Won : 0.7574, Environment Won : 0.0891, Tie(s) : 0.1535
# After playing 3730000 games, Agent Won : 0.7579, Environment Won : 0.0889, Tie(s) : 0.1532
# After playing 3740000 games, Agent Won : 0.7584, Environment Won : 0.0887, Tie(s) : 0.1529
# After playing 3750000 games, Agent Won : 0.7589, Environment Won : 0.0885, Tie(s) : 0.1526
# After playing 3760000 games, Agent Won : 0.7594, Environment Won : 0.0883, Tie(s) : 0.1523
# After playing 3770000 games, Agent Won : 0.7598, Environment Won : 0.0881, Tie(s) : 0.1520
# After playing 3780000 games, Agent Won : 0.7603, Environment Won : 0.0880, Tie(s) : 0.1517
# After playing 3790000 games, Agent Won : 0.7608, Environment Won : 0.0878, Tie(s) : 0.1514
# After playing 3800000 games, Agent Won : 0.7613, Environment Won : 0.0876, Tie(s) : 0.1511
# After playing 3810000 games, Agent Won : 0.7618, Environment Won : 0.0874, Tie(s) : 0.1508
# After playing 3820000 games, Agent Won : 0.7623, Environment Won : 0.0872, Tie(s) : 0.1505
# After playing 3830000 games, Agent Won : 0.7627, Environment Won : 0.0871, Tie(s) : 0.1502
# After playing 3840000 games, Agent Won : 0.7632, Environment Won : 0.0869, Tie(s) : 0.1499
# After playing 3850000 games, Agent Won : 0.7637, Environment Won : 0.0867, Tie(s) : 0.1496
# After playing 3860000 games, Agent Won : 0.7641, Environment Won : 0.0865, Tie(s) : 0.1493
# After playing 3870000 games, Agent Won : 0.7646, Environment Won : 0.0864, Tie(s) : 0.1490
# After playing 3880000 games, Agent Won : 0.7651, Environment Won : 0.0862, Tie(s) : 0.1488
# After playing 3890000 games, Agent Won : 0.7655, Environment Won : 0.0860, Tie(s) : 0.1485
# After playing 3900000 games, Agent Won : 0.7660, Environment Won : 0.0858, Tie(s) : 0.1482
# After playing 3910000 games, Agent Won : 0.7664, Environment Won : 0.0857, Tie(s) : 0.1479
# After playing 3920000 games, Agent Won : 0.7669, Environment Won : 0.0855, Tie(s) : 0.1476
# After playing 3930000 games, Agent Won : 0.7673, Environment Won : 0.0853, Tie(s) : 0.1473
# After playing 3940000 games, Agent Won : 0.7678, Environment Won : 0.0852, Tie(s) : 0.1471
# After playing 3950000 games, Agent Won : 0.7682, Environment Won : 0.0850, Tie(s) : 0.1468
# After playing 3960000 games, Agent Won : 0.7687, Environment Won : 0.0848, Tie(s) : 0.1465
# After playing 3970000 games, Agent Won : 0.7691, Environment Won : 0.0847, Tie(s) : 0.1462
# After playing 3980000 games, Agent Won : 0.7696, Environment Won : 0.0845, Tie(s) : 0.1459
# After playing 3990000 games, Agent Won : 0.7700, Environment Won : 0.0843, Tie(s) : 0.1457
# After playing 4000000 games, Agent Won : 0.7705, Environment Won : 0.0842, Tie(s) : 0.1454
# After playing 4010000 games, Agent Won : 0.7709, Environment Won : 0.0840, Tie(s) : 0.1451
# After playing 4020000 games, Agent Won : 0.7713, Environment Won : 0.0838, Tie(s) : 0.1448
# After playing 4030000 games, Agent Won : 0.7718, Environment Won : 0.0837, Tie(s) : 0.1446
# After playing 4040000 games, Agent Won : 0.7722, Environment Won : 0.0835, Tie(s) : 0.1443
# After playing 4050000 games, Agent Won : 0.7726, Environment Won : 0.0834, Tie(s) : 0.1440
# After playing 4060000 games, Agent Won : 0.7730, Environment Won : 0.0832, Tie(s) : 0.1438
# After playing 4070000 games, Agent Won : 0.7734, Environment Won : 0.0830, Tie(s) : 0.1435
# After playing 4080000 games, Agent Won : 0.7739, Environment Won : 0.0829, Tie(s) : 0.1433
# After playing 4090000 games, Agent Won : 0.7743, Environment Won : 0.0827, Tie(s) : 0.1430
# After playing 4100000 games, Agent Won : 0.7747, Environment Won : 0.0826, Tie(s) : 0.1427
# After playing 4110000 games, Agent Won : 0.7751, Environment Won : 0.0824, Tie(s) : 0.1425
# After playing 4120000 games, Agent Won : 0.7755, Environment Won : 0.0823, Tie(s) : 0.1422
# After playing 4130000 games, Agent Won : 0.7759, Environment Won : 0.0821, Tie(s) : 0.1420
# After playing 4140000 games, Agent Won : 0.7763, Environment Won : 0.0820, Tie(s) : 0.1417
# After playing 4150000 games, Agent Won : 0.7767, Environment Won : 0.0818, Tie(s) : 0.1415
# After playing 4160000 games, Agent Won : 0.7771, Environment Won : 0.0817, Tie(s) : 0.1412
# After playing 4170000 games, Agent Won : 0.7775, Environment Won : 0.0815, Tie(s) : 0.1410
# After playing 4180000 games, Agent Won : 0.7779, Environment Won : 0.0814, Tie(s) : 0.1407
# After playing 4190000 games, Agent Won : 0.7783, Environment Won : 0.0812, Tie(s) : 0.1405
# After playing 4200000 games, Agent Won : 0.7787, Environment Won : 0.0811, Tie(s) : 0.1402
# After playing 4210000 games, Agent Won : 0.7791, Environment Won : 0.0809, Tie(s) : 0.1400
# After playing 4220000 games, Agent Won : 0.7795, Environment Won : 0.0808, Tie(s) : 0.1397
# After playing 4230000 games, Agent Won : 0.7799, Environment Won : 0.0806, Tie(s) : 0.1395
# After playing 4240000 games, Agent Won : 0.7803, Environment Won : 0.0805, Tie(s) : 0.1392
# After playing 4250000 games, Agent Won : 0.7807, Environment Won : 0.0803, Tie(s) : 0.1390
# After playing 4260000 games, Agent Won : 0.7811, Environment Won : 0.0802, Tie(s) : 0.1388
# After playing 4270000 games, Agent Won : 0.7814, Environment Won : 0.0800, Tie(s) : 0.1385
# After playing 4280000 games, Agent Won : 0.7818, Environment Won : 0.0799, Tie(s) : 0.1383
# After playing 4290000 games, Agent Won : 0.7822, Environment Won : 0.0798, Tie(s) : 0.1381
# After playing 4300000 games, Agent Won : 0.7826, Environment Won : 0.0796, Tie(s) : 0.1378
# After playing 4310000 games, Agent Won : 0.7829, Environment Won : 0.0795, Tie(s) : 0.1376
# After playing 4320000 games, Agent Won : 0.7833, Environment Won : 0.0793, Tie(s) : 0.1374
# After playing 4330000 games, Agent Won : 0.7837, Environment Won : 0.0792, Tie(s) : 0.1371
# After playing 4340000 games, Agent Won : 0.7841, Environment Won : 0.0790, Tie(s) : 0.1369
# After playing 4350000 games, Agent Won : 0.7844, Environment Won : 0.0789, Tie(s) : 0.1366
# After playing 4360000 games, Agent Won : 0.7848, Environment Won : 0.0788, Tie(s) : 0.1364
# After playing 4370000 games, Agent Won : 0.7852, Environment Won : 0.0786, Tie(s) : 0.1362
# After playing 4380000 games, Agent Won : 0.7855, Environment Won : 0.0785, Tie(s) : 0.1360
# After playing 4390000 games, Agent Won : 0.7859, Environment Won : 0.0784, Tie(s) : 0.1357
# After playing 4400000 games, Agent Won : 0.7862, Environment Won : 0.0782, Tie(s) : 0.1355
# After playing 4410000 games, Agent Won : 0.7866, Environment Won : 0.0781, Tie(s) : 0.1353
# After playing 4420000 games, Agent Won : 0.7869, Environment Won : 0.0780, Tie(s) : 0.1351
# After playing 4430000 games, Agent Won : 0.7873, Environment Won : 0.0778, Tie(s) : 0.1349
# After playing 4440000 games, Agent Won : 0.7876, Environment Won : 0.0777, Tie(s) : 0.1347
# After playing 4450000 games, Agent Won : 0.7880, Environment Won : 0.0776, Tie(s) : 0.1344
# After playing 4460000 games, Agent Won : 0.7883, Environment Won : 0.0774, Tie(s) : 0.1342
# After playing 4470000 games, Agent Won : 0.7887, Environment Won : 0.0773, Tie(s) : 0.1340
# After playing 4480000 games, Agent Won : 0.7890, Environment Won : 0.0772, Tie(s) : 0.1338
# After playing 4490000 games, Agent Won : 0.7894, Environment Won : 0.0771, Tie(s) : 0.1336
# After playing 4500000 games, Agent Won : 0.7897, Environment Won : 0.0769, Tie(s) : 0.1334
# After playing 4510000 games, Agent Won : 0.7901, Environment Won : 0.0768, Tie(s) : 0.1331
# After playing 4520000 games, Agent Won : 0.7904, Environment Won : 0.0767, Tie(s) : 0.1329
# After playing 4530000 games, Agent Won : 0.7907, Environment Won : 0.0765, Tie(s) : 0.1327
# After playing 4540000 games, Agent Won : 0.7911, Environment Won : 0.0764, Tie(s) : 0.1325
# After playing 4550000 games, Agent Won : 0.7914, Environment Won : 0.0763, Tie(s) : 0.1323
# After playing 4560000 games, Agent Won : 0.7918, Environment Won : 0.0762, Tie(s) : 0.1321
# After playing 4570000 games, Agent Won : 0.7921, Environment Won : 0.0760, Tie(s) : 0.1319
# After playing 4580000 games, Agent Won : 0.7924, Environment Won : 0.0759, Tie(s) : 0.1317
# After playing 4590000 games, Agent Won : 0.7927, Environment Won : 0.0758, Tie(s) : 0.1315
# After playing 4600000 games, Agent Won : 0.7931, Environment Won : 0.0757, Tie(s) : 0.1313
# After playing 4610000 games, Agent Won : 0.7934, Environment Won : 0.0755, Tie(s) : 0.1311
# After playing 4620000 games, Agent Won : 0.7937, Environment Won : 0.0754, Tie(s) : 0.1309
# After playing 4630000 games, Agent Won : 0.7941, Environment Won : 0.0753, Tie(s) : 0.1307
# After playing 4640000 games, Agent Won : 0.7944, Environment Won : 0.0752, Tie(s) : 0.1305
# After playing 4650000 games, Agent Won : 0.7947, Environment Won : 0.0750, Tie(s) : 0.1303
# After playing 4660000 games, Agent Won : 0.7950, Environment Won : 0.0749, Tie(s) : 0.1301
# After playing 4670000 games, Agent Won : 0.7953, Environment Won : 0.0748, Tie(s) : 0.1299
# After playing 4680000 games, Agent Won : 0.7957, Environment Won : 0.0747, Tie(s) : 0.1297
# After playing 4690000 games, Agent Won : 0.7960, Environment Won : 0.0746, Tie(s) : 0.1295
# After playing 4700000 games, Agent Won : 0.7963, Environment Won : 0.0744, Tie(s) : 0.1293
# After playing 4710000 games, Agent Won : 0.7966, Environment Won : 0.0743, Tie(s) : 0.1291
# After playing 4720000 games, Agent Won : 0.7969, Environment Won : 0.0742, Tie(s) : 0.1289
# After playing 4730000 games, Agent Won : 0.7972, Environment Won : 0.0741, Tie(s) : 0.1287
# After playing 4740000 games, Agent Won : 0.7976, Environment Won : 0.0740, Tie(s) : 0.1285
# After playing 4750000 games, Agent Won : 0.7979, Environment Won : 0.0738, Tie(s) : 0.1283
# After playing 4760000 games, Agent Won : 0.7982, Environment Won : 0.0737, Tie(s) : 0.1281
# After playing 4770000 games, Agent Won : 0.7985, Environment Won : 0.0736, Tie(s) : 0.1279
# After playing 4780000 games, Agent Won : 0.7988, Environment Won : 0.0735, Tie(s) : 0.1277
# After playing 4790000 games, Agent Won : 0.7991, Environment Won : 0.0734, Tie(s) : 0.1275
# After playing 4800000 games, Agent Won : 0.7994, Environment Won : 0.0733, Tie(s) : 0.1273
# After playing 4810000 games, Agent Won : 0.7997, Environment Won : 0.0732, Tie(s) : 0.1271
# After playing 4820000 games, Agent Won : 0.8000, Environment Won : 0.0731, Tie(s) : 0.1269
# After playing 4830000 games, Agent Won : 0.8003, Environment Won : 0.0729, Tie(s) : 0.1268
# After playing 4840000 games, Agent Won : 0.8006, Environment Won : 0.0728, Tie(s) : 0.1266
# After playing 4850000 games, Agent Won : 0.8009, Environment Won : 0.0727, Tie(s) : 0.1264
# After playing 4860000 games, Agent Won : 0.8012, Environment Won : 0.0726, Tie(s) : 0.1262
# After playing 4870000 games, Agent Won : 0.8015, Environment Won : 0.0725, Tie(s) : 0.1260
# After playing 4880000 games, Agent Won : 0.8017, Environment Won : 0.0724, Tie(s) : 0.1259
# After playing 4890000 games, Agent Won : 0.8020, Environment Won : 0.0723, Tie(s) : 0.1257
# After playing 4900000 games, Agent Won : 0.8023, Environment Won : 0.0722, Tie(s) : 0.1255
# After playing 4910000 games, Agent Won : 0.8026, Environment Won : 0.0721, Tie(s) : 0.1253
# After playing 4920000 games, Agent Won : 0.8029, Environment Won : 0.0720, Tie(s) : 0.1251
# After playing 4930000 games, Agent Won : 0.8032, Environment Won : 0.0718, Tie(s) : 0.1250
# After playing 4940000 games, Agent Won : 0.8035, Environment Won : 0.0717, Tie(s) : 0.1248
# After playing 4950000 games, Agent Won : 0.8038, Environment Won : 0.0716, Tie(s) : 0.1246
# After playing 4960000 games, Agent Won : 0.8040, Environment Won : 0.0715, Tie(s) : 0.1244
# After playing 4970000 games, Agent Won : 0.8043, Environment Won : 0.0714, Tie(s) : 0.1243
# After playing 4980000 games, Agent Won : 0.8046, Environment Won : 0.0713, Tie(s) : 0.1241
# After playing 4990000 games, Agent Won : 0.8049, Environment Won : 0.0712, Tie(s) : 0.1239
# After playing 5000000 games, Agent Won : 0.8052, Environment Won : 0.0711, Tie(s) : 0.1237
# Elapsed time : 7906.900446653366

# %%
save_obj(States_track,dir_to_save + '/States_tracked_final.pickle')
save_obj(Q_dict,dir_to_save + '/Policy_final.pickle')

# %%
save_obj(agent_won_list,dir_to_save + "/agent_won_list.pickle")
save_obj(env_won_list,dir_to_save + "/env_won_list.pickle")
save_obj(tie_list,dir_to_save + "/game_tie_list.pickle")

# %%
plt.figure(figsize=(20,5))
plt.plot(range(0,5000000),np.array(agent_won_list)/np.array(list(range(1,5000001))))
plt.plot(range(0,5000000),np.array(env_won_list)/np.array(list(range(1,5000001))))
plt.plot(range(0,5000000),np.array(tie_list)/np.array(list(range(1,5000001))))
plt.xlabel("Percentage")
plt.ylabel("Number of games played")
plt.title("Agent Winning (%)/ Environment Winning (%)/ Game Ties(%)")
plt.legend(["Agent Won(%)","Environment Won(%)","Game Ties(%)"],loc="upper right")
plt.show()

# %% [markdown]
# Checking convergence of state values for saved_tracking states
#
# **Important**
#
# We present the convergence graph of only 1 state+action pair below, similar to below, we can plot covergence graph for other state+action pairs also.

# %%
# check saved saved_states for convergence #
plt.figure(figsize=(20,5))
plt.plot(range(0,125),States_track['x-1-x-x-x-x-8-6-7'][(0,3)])
plt.xlabel("Game iterations")
plt.ylabel("Q_value")
plt.title("State : x-1-x-x-x-x-8-6-7 - action : (0,3) - Q_value Update graph")
plt.legend(["Q-value"],loc="lower right")
plt.show()
